# %%
import pandas as pd

path = 'D:\DS\EDA\IT Salary Survey EU\IT Salary Survey EU 2018.csv'

df = pd.read_csv(path, header = 0)
df
# Out:
#                Timestamp   Age Gender     City                       Position  \
# 0    14/12/2018 12:41:33  43.0      M  München                   QA Ingenieur
# 1    14/12/2018 12:42:09  33.0      F  München  Senior PHP Magento developer
# 2    14/12/2018 12:47:36  32.0      M  München              Software Engineer
# 3    14/12/2018 12:50:15  25.0      M  München      Senior Frontend Developer
# 4    14/12/2018 12:50:31  39.0      M  München                    UX Designer
# ..                   ...   ...    ...      ...                            ...
# 760  03/06/2020 20:12:51  40.0      M     Köln          Java Developer junior
# 761  28/07/2020 04:03:13   NaN      M     Köln              E.g. C# Developer
# 762  28/07/2020 04:03:20   NaN      M     Köln              E.g. C# Developer
# 763  26/08/2020 09:06:44   NaN    NaN      NaN                            NaN
# 764  21/09/2020 01:47:10  31.0      F  München                            Pm
#
# ...

# %%
# 	Timestamp
df.shape
# Out:
# (765, 14)

# %%
df.pop('Timestamp')
# Out:
# 0      14/12/2018 12:41:33
# 1      14/12/2018 12:42:09
# 2      14/12/2018 12:47:36
# 3      14/12/2018 12:50:15
# 4      14/12/2018 12:50:31
#               ...
# 760    03/06/2020 20:12:51
# 761    28/07/2020 04:03:13
# 762    28/07/2020 04:03:20
# 763    26/08/2020 09:06:44
# 764    21/09/2020 01:47:10
# Name: Timestamp, Length: 765, dtype: object

# %%
df
# Out:
#       Age Gender     City                       Position  Years of experience  \
# 0    43.0      M  München                   QA Ingenieur                 11.0
# 1    33.0      F  München  Senior PHP Magento developer                   8.0
# 2    32.0      M  München              Software Engineer                 10.0
# 3    25.0      M  München      Senior Frontend Developer                  6.0
# 4    39.0      M  München                    UX Designer                 10.0
# ..    ...    ...      ...                            ...                  ...
# 760  40.0      M     Köln          Java Developer junior                  1.0
# 761   NaN      M     Köln              E.g. C# Developer                  1.0
# 762   NaN      M     Köln              E.g. C# Developer                  1.0
# 763   NaN    NaN      NaN                            NaN                  NaN
# 764  31.0      F  München                            Pm                  10.0
#
# ...

# %%
df.columns = df.columns.to_series().apply(lambda x: x.strip())

# %%
df
# Out:
#       Age Gender     City                       Position  Years of experience  \
# 0    43.0      M  München                   QA Ingenieur                 11.0
# 1    33.0      F  München  Senior PHP Magento developer                   8.0
# 2    32.0      M  München              Software Engineer                 10.0
# 3    25.0      M  München      Senior Frontend Developer                  6.0
# 4    39.0      M  München                    UX Designer                 10.0
# ..    ...    ...      ...                            ...                  ...
# 760  40.0      M     Köln          Java Developer junior                  1.0
# 761   NaN      M     Köln              E.g. C# Developer                  1.0
# 762   NaN      M     Köln              E.g. C# Developer                  1.0
# 763   NaN    NaN      NaN                            NaN                  NaN
# 764  31.0      F  München                            Pm                  10.0
#
# ...

# %%
df.head()
# Out:
#     Age Gender     City                       Position  Years of experience  \
# 0  43.0      M  München                   QA Ingenieur                 11.0
# 1  33.0      F  München  Senior PHP Magento developer                   8.0
# 2  32.0      M  München              Software Engineer                 10.0
# 3  25.0      M  München      Senior Frontend Developer                  6.0
# 4  39.0      M  München                    UX Designer                 10.0
#
#   Your level  Current Salary  Salary one year ago  Salary two years ago  \
# 0     Senior         77000.0              76200.0               68000.0
# 1     Senior         65000.0              55000.0               55000.0
# 2     Senior         88000.0              73000.0               54000.0
# 3     Senior         78000.0              55000.0               45000.0
# 4     Senior         69000.0              60000.0               52000.0
#
#   Are you getting any Stock Options? Main language at work Company size  \
# ...

# %%
df.shape
# Out:
# (765, 13)

# %%
df.tail()
# Out:
#       Age Gender     City               Position  Years of experience  \
# 760  40.0      M     Köln  Java Developer junior                  1.0
# 761   NaN      M     Köln      E.g. C# Developer                  1.0
# 762   NaN      M     Köln      E.g. C# Developer                  1.0
# 763   NaN    NaN      NaN                    NaN                  NaN
# 764  31.0      F  München                    Pm                  10.0
#
#     Your level  Current Salary  Salary one year ago  Salary two years ago  \
# 760     Junior         44000.0              40000.0               40000.0
# 761     Junior         45000.0              40000.0               40000.0
# 762     Junior         45000.0              40000.0               40000.0
# 763        NaN             NaN                  NaN                   NaN
# 764     Senior        110000.0                  NaN                   NaN
#
#     Are you getting any Stock Options? Main language at work Company size  \
# ...

# %%
df.isnull().sum()
# Out:
# Age                                    93
# Gender                                 14
# City                                   29
# Position                               28
# Years of experience                    33
# Your level                             22
# Current Salary                         15
# Salary one year ago                   169
# Salary two years ago                  302
# Are you getting any Stock Options?     23
# Main language at work                  15
# Company size                           15
# Company type                           35
# dtype: int64

# %%
df.dtypes
# Out:
# Age                                   float64
# Gender                                 object
# City                                   object
# Position                               object
# Years of experience                   float64
# Your level                             object
# Current Salary                        float64
# Salary one year ago                   float64
# Salary two years ago                  float64
# Are you getting any Stock Options?     object
# Main language at work                  object
# Company size                           object
# Company type                           object
# dtype: object

# %%
df.rename(columns = {'Current Salary':'Yearly Salary'}, inplace = True)

# %%
df
# Out:
#       Age Gender     City                       Position  Years of experience  \
# 0    43.0      M  München                   QA Ingenieur                 11.0
# 1    33.0      F  München  Senior PHP Magento developer                   8.0
# 2    32.0      M  München              Software Engineer                 10.0
# 3    25.0      M  München      Senior Frontend Developer                  6.0
# 4    39.0      M  München                    UX Designer                 10.0
# ..    ...    ...      ...                            ...                  ...
# 760  40.0      M     Köln          Java Developer junior                  1.0
# 761   NaN      M     Köln              E.g. C# Developer                  1.0
# 762   NaN      M     Köln              E.g. C# Developer                  1.0
# 763   NaN    NaN      NaN                            NaN                  NaN
# 764  31.0      F  München                            Pm                  10.0
#
# ...

# %%
df.rename(columns = {'Your level':'Seniority Level'}, inplace = True)

# %%
df
# Out:
#       Age Gender     City                       Position  Years of experience  \
# 0    43.0      M  München                   QA Ingenieur                 11.0
# 1    33.0      F  München  Senior PHP Magento developer                   8.0
# 2    32.0      M  München              Software Engineer                 10.0
# 3    25.0      M  München      Senior Frontend Developer                  6.0
# 4    39.0      M  München                    UX Designer                 10.0
# ..    ...    ...      ...                            ...                  ...
# 760  40.0      M     Köln          Java Developer junior                  1.0
# 761   NaN      M     Köln              E.g. C# Developer                  1.0
# 762   NaN      M     Köln              E.g. C# Developer                  1.0
# 763   NaN    NaN      NaN                            NaN                  NaN
# 764  31.0      F  München                            Pm                  10.0
#
# ...

# %%
df.isnull().sum()
# Out:
# Age                                    93
# Gender                                 14
# City                                   29
# Position                               28
# Years of experience                    33
# Seniority Level                        22
# Yearly Salary                          15
# Salary one year ago                   169
# Salary two years ago                  302
# Are you getting any Stock Options?     23
# Main language at work                  15
# Company size                           15
# Company type                           35
# dtype: int64

# %%
df.select_dtypes(include = ['float64'])
# Out:
#       Age  Years of experience  Yearly Salary  Salary one year ago  \
# 0    43.0                 11.0        77000.0              76200.0
# 1    33.0                  8.0        65000.0              55000.0
# 2    32.0                 10.0        88000.0              73000.0
# 3    25.0                  6.0        78000.0              55000.0
# 4    39.0                 10.0        69000.0              60000.0
# ..    ...                  ...            ...                  ...
# 760  40.0                  1.0        44000.0              40000.0
# 761   NaN                  1.0        45000.0              40000.0
# 762   NaN                  1.0        45000.0              40000.0
# 763   NaN                  NaN            NaN                  NaN
# 764  31.0                 10.0       110000.0                  NaN
#
#      Salary two years ago
# 0                 68000.0
# 1                 55000.0
# 2                 54000.0
# 3                 45000.0
# ...

# %%
df.dtypes
# Out:
# Age                                   float64
# Gender                                 object
# City                                   object
# Position                               object
# Years of experience                   float64
# Seniority Level                        object
# Yearly Salary                         float64
# Salary one year ago                   float64
# Salary two years ago                  float64
# Are you getting any Stock Options?     object
# Main language at work                  object
# Company size                           object
# Company type                           object
# dtype: object

# %%
df['Gender'] = df['Gender'].fillna('Undefined')

# %%
 df['Gender'].isnull().values.any()
# Out:
# False

# %%
df.select_dtypes(include = ['object'])
# Out:
#         Gender     City                       Position Seniority Level  \
# 0            M  München                   QA Ingenieur          Senior
# 1            F  München  Senior PHP Magento developer           Senior
# 2            M  München              Software Engineer          Senior
# 3            M  München      Senior Frontend Developer          Senior
# 4            M  München                    UX Designer          Senior
# ..         ...      ...                            ...             ...
# 760          M     Köln          Java Developer junior          Junior
# 761          M     Köln              E.g. C# Developer          Junior
# 762          M     Köln              E.g. C# Developer          Junior
# 763  Undefined      NaN                            NaN             NaN
# 764          F  München                            Pm           Senior
#
#     Are you getting any Stock Options? Main language at work Company size  \
# ...

# %%
df['City'] = df['City'].fillna('Undefined')
df['Position'] = df['Position'].fillna('Undefined')
df['Seniority Level'] = df['Seniority Level'].fillna('Undefined')
df['Are you getting any Stock Options?'] = df['Are you getting any Stock Options?'].fillna('Undefined')
df['Main language at work'] = df['Main language at work'].fillna('Undefined')
df['Company size'] = df['Company size'].fillna('Undefined')
df['Company type'] = df['Company type'].fillna('Undefined')

# %%
df.isnull().sum()
# Out:
# Age                                    93
# Gender                                  0
# City                                    0
# Position                                0
# Years of experience                    33
# Seniority Level                         0
# Yearly Salary                          15
# Salary one year ago                   169
# Salary two years ago                  302
# Are you getting any Stock Options?      0
# Main language at work                   0
# Company size                            0
# Company type                            0
# dtype: int64

# %%
df.select_dtypes(include = ['float64'])
# Out:
#       Age  Years of experience  Yearly Salary  Salary one year ago  \
# 0    43.0                 11.0        77000.0              76200.0
# 1    33.0                  8.0        65000.0              55000.0
# 2    32.0                 10.0        88000.0              73000.0
# 3    25.0                  6.0        78000.0              55000.0
# 4    39.0                 10.0        69000.0              60000.0
# ..    ...                  ...            ...                  ...
# 760  40.0                  1.0        44000.0              40000.0
# 761   NaN                  1.0        45000.0              40000.0
# 762   NaN                  1.0        45000.0              40000.0
# 763   NaN                  NaN            NaN                  NaN
# 764  31.0                 10.0       110000.0                  NaN
#
#      Salary two years ago
# 0                 68000.0
# 1                 55000.0
# 2                 54000.0
# 3                 45000.0
# ...

# %%
#df.fillna(df.dtypes.replace({'float64': 0.0, 'O': '0'}), downcast='infer', inplace=True)
df['Age'] = df['Age'].fillna('Not mentioned')

# %%
df['Age'] = df['Age'].fillna('Not mentioned')

# %%
import numpy as np
df["Age"].replace({"Not mentioned": np.nan}, inplace=True)

# %% [markdown]
# ## Orginal Averages

# %%
Ageavg = df['Age'].mean(skipna = True)
Expavg = df['Years of experience'].mean(skipna = True)
Salavg = df['Yearly Salary'].mean(skipna = True)
Sal1ago = df['Salary one year ago'].mean(skipna = True)
Sal2ago = df['Salary two years ago'].mean(skipna = True)
print(Ageavg,Expavg,Salavg,Sal1ago,Sal2ago)
# Out:
# 32.183035714285715 8.548497267759563 68381.76533333333 62187.278523489935 58013.475161987044

# %%
df['Age'] = df['Age'].fillna('Not mentioned')
df
# Out:
#                Age     Gender       City                       Position  \
# 0             43.0          M    München                   QA Ingenieur
# 1             33.0          F    München  Senior PHP Magento developer
# 2             32.0          M    München              Software Engineer
# 3             25.0          M    München      Senior Frontend Developer
# 4             39.0          M    München                    UX Designer
# ..             ...        ...        ...                            ...
# 760           40.0          M       Köln          Java Developer junior
# 761  Not mentioned          M       Köln              E.g. C# Developer
# 762  Not mentioned          M       Köln              E.g. C# Developer
# 763  Not mentioned  Undefined  Undefined                      Undefined
# 764           31.0          F    München                            Pm
#
#      Years of experience Seniority Level  Yearly Salary  Salary one year ago  \
# ...

# %%
df['Position'].value_counts().plot(kind='barh',figsize = (10,70), orientation=u'horizontal', align='edge')
# Out:
# <AxesSubplot:>

# %%
poscount = df['Position'].value_counts()
print(poscount)
# Out:
# Java Developer                  34
# Software Engineer               29
# Undefined                       28
# Senior Software Engineer        16
# QA                              15
#                                 ..
# Software Engineer JavaSctipt     1
# Oracle Developer                 1
# Lead Developer                   1
# java fullsteck developer         1
# Head of Data Science             1
# Name: Position, Length: 398, dtype: int64

# %%
df.to_csv('IT Salary Survey2018_Cleaned.csv',index = False)

# %%
ls
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is 2CB6-6900
#
#  Directory of D:\DS\EDA\IT Salary Survey EU
#
# 30-01-2022  02:30    <DIR>          .
# 17-12-2021  22:35    <DIR>          ..
# 25-01-2022  22:01    <DIR>          .ipynb_checkpoints
# 11-12-2021  15:47           238,182 IT Salary Survey EU  2020.csv
# 11-12-2021  15:47            77,161 IT Salary Survey EU 2018.csv
# 01-02-2022  18:25            71,099 IT Salary Survey2018_Cleaned.csv
# 30-01-2022  02:30         1,069,279 IT Salary18.ipynb
# 11-12-2021  22:46           244,001 IT Salary20.ipynb
# 29-01-2022  21:58            13,611 Position18Revised.csv
# 11-12-2021  16:50           220,579 Revised 2020.csv
# 11-12-2021  15:47           141,780 T Salary Survey EU 2019.csv
# 04-01-2022  22:37         1,242,788 Untitled.ipynb
#                9 File(s)      3,318,480 bytes
#                3 Dir(s)  394,066,141,184 bytes free

# %%
df['Position'].value_counts().to_frame
# Out:
# <bound method Series.to_frame of Java Developer                  34
# Software Engineer               29
# Undefined                       28
# Senior Software Engineer        16
# QA                              15
#                                 ..
# Software Engineer JavaSctipt     1
# Oracle Developer                 1
# Lead Developer                   1
# java fullsteck developer         1
# Head of Data Science             1
# Name: Position, Length: 398, dtype: int64>

# %%
df['Position'].to_csv('Position18Revised.csv',index = False, header = False)

# %%
df['Gender'].value_counts()
# Out:
# M            646
# F            105
# Undefined     14
# Name: Gender, dtype: int64

# %%
df['Seniority Level'].value_counts()
# Out:
# Senior       497
# Middle       206
# Junior        40
# Undefined     22
# Name: Seniority Level, dtype: int64

# %%
yoemax = df['Years of experience'].max()
print(yoemax)
# Out:
# 38.0

# %%
yoemin = df['Years of experience'].min()
print(yoemin)
# Out:
# 0.0

# %%
df['Are you getting any Stock Options?'].value_counts()
# Out:
# No           587
# Yes          155
# Undefined     23
# Name: Are you getting any Stock Options?, dtype: int64

# %%
yearsalmin = df['Yearly Salary'].min()
yearsalmax = df['Yearly Salary'].max()
print(yearsalmin, yearsalmax)
# Out:
# 10300.0 200000.0

# %%
df['Main language at work'].value_counts()
# Out:
# English                                  581
# Deutsch                                  134
# Russian                                   29
# Undefined                                 15
# Polish                                     2
# French                                     2
# Deutsch/Englisch                           1
# Team - Russian; Cross-team - English;      1
# Name: Main language at work, dtype: int64

# %%
df['Company size'].value_counts()
# Out:
# 100-1000     260
# 1000+        219
# 50-100       120
# 10-50        117
# up to 10      34
# Undefined     15
# Name: Company size, dtype: int64

# %%
df['Company type'].value_counts()
# Out:
# Product                                      451
# Startup                                      145
# Agency                                        74
# Undefined                                     35
# Consulting                                     5
# Outsource                                      5
# Outsourcing                                    3
# Insurance                                      2
# Consultancy                                    2
# Automotive                                     2
# Corporation                                    2
# Fin Tech                                       1
# Retail                                         1
# Ecom retailer                                  1
# ISP                                            1
# Ecommerce                                      1
# E-Commerce firm                                1
# Hochschule/university                          1
# Big Tech                                       1
# ...

# %%
df["Company type"].replace({"Outsourcing": "Outsource"}, inplace=True)
df["Company type"].replace({"Outsorce": "Outsource"}, inplace=True)
df["Company type"].replace({"Consulting (banking)": "Consulting"}, inplace=True)
df["Company type"].replace({"Consultancy": "Consulting"}, inplace=True)
df["Company type"].replace({"Consult": "Consulting"}, inplace=True)
df["Company type"].replace({"IT-Beratung": "Consulting"}, inplace=True)
df["Company type"].replace({"IT Consulting": "Consulting"}, inplace=True)
df["Company type"].replace({"IT Consultancy": "Consulting"}, inplace=True)
df["Company type"].replace({"Consulting Company": "Consulting"}, inplace=True)
df["Company type"].replace({"consulting": "Consulting"}, inplace=True)
df["Company type"].replace({"Technology Consulting": "Consulting"}, inplace=True)
df["Company type"].replace({"IT Consultants": "Consulting"}, inplace=True)
df["Company type"].replace({"outsource": "Outsource"}, inplace=True)
df["Company type"].replace({"Ecom retailer":"E-Commerce"},inplace = True)
df["Company type"].replace({"e-commerce":"E-Commerce"},inplace = True)
df["Company type"].replace({"Ecommerce":"E-Commerce"},inplace = True)
df["Company type"].replace({"E-Commerce firm":"E-Commerce"},inplace = True)
df["Company type"].replace({"Product and Projects":"Product"},inplace = True)
df["Company type"].replace({"Retail":"E-Commerce"},inplace = True)
df['Company type'].value_counts()
# Out:
# Product                                      452
# Startup                                      145
# Agency                                        74
# Undefined                                     35
# Consulting                                    15
# Outsource                                     10
# E-Commerce                                     6
# Insurance                                      2
# Corporation                                    2
# Automotive                                     2
# Hochschule/university                          1
# non-IT, manufacturing                          1
# Big Tech                                       1
# IT Consulting                                  1
# IT Service Provider                            1
# Fin Tech                                       1
# ISP                                            1
# Bank                                           1
# telecom operator                               1
# ...

# %%
df['Company type'].value_counts()
# Out:
# Product                                      452
# Startup                                      145
# Agency                                        74
# Undefined                                     35
# Consulting                                    15
# Outsource                                     10
# E-Commerce                                     6
# Insurance                                      2
# Corporation                                    2
# Automotive                                     2
# Hochschule/university                          1
# non-IT, manufacturing                          1
# Big Tech                                       1
# IT Consulting                                  1
# IT Service Provider                            1
# Fin Tech                                       1
# ISP                                            1
# Bank                                           1
# telecom operator                               1
# ...

# %%
df['Position'].replace({"QA Ingenieur":"QA"},inplace = True)
df['Position'].replace({"QA Lead":"QA"},inplace = True)
df['Position'].replace({"QA Test Engineer":"QA"},inplace = True)
df['Position'].replace({"QA Manager":"QA"},inplace = True)
df['Position'].replace({"QA Engineer":"QA"},inplace = True)
df['Position'].replace({"Automation QA":"QA"},inplace = True)
df['Position'].replace({"Manual QA":"QA"},inplace = True)
df['Position'].replace({"QA Consultant":"QA"},inplace = True)
df['Position'].replace({"QA Automation Engineer":"QA"},inplace = True)
df['Position'].replace({"qa ta architect":"QA"},inplace = True)
df['Position'].replace({"Senior automation qa":"QA"},inplace = True)
df['Position'].replace({"QA automation":"QA"},inplace = True)
df['Position'].replace({"qa":"QA"},inplace = True)
df['Position'].replace({"Senior QA Engineer":"QA"},inplace = True)
df['Position'].value_counts()
# Out:
# QA                                36
# Java Developer                    34
# Software Engineer                 29
# Undefined                         28
# Senior Software Engineer          16
#                                   ..
# Site Reliability engineer          1
# Senior Software Ingenieur Java     1
# Graphic Designer                   1
# MTS                                1
# DWH expert                         1
# Name: Position, Length: 386, dtype: int64

# %%
df['Position'].replace({"Java Fullstack Developer":"Java Developer"},inplace = True)
df['Position'].replace({"Senior Java Developer":"Java Developer"},inplace = True)
df['Position'].replace({"Senior Java":"Java Developer"},inplace = True)
df['Position'].replace({"Java developer":"Java Developer"},inplace = True)
df['Position'].replace({"Java Software Engineer":"Java Developer"},inplace = True)
df['Position'].replace({"Senior Software Ingenieur Java":"Java Developer"},inplace = True)
df['Position'].replace({"java fullsteck developer":"Java Developer"},inplace = True)
df['Position'].replace({"java developer":"Java Developer"},inplace = True)
df['Position'].replace({"Java dev":"Java Developer"},inplace = True)
df['Position'].replace({"Java Team Lead":"Java Developer"},inplace = True)
df['Position'].replace({"Software Engineer (java)":"Java Developer"},inplace = True)
df['Position'].replace({"Java Full-Stack Developer":"Java Developer"},inplace = True)
df['Position'].replace({"Lead Java Developer":"Java Developer"},inplace = True)
df['Position'].replace({" Java Developer":"Java Developer"},inplace = True)
df['Position'].replace({"Senior Java developer":"Java Developer"},inplace = True)
df['Position'].replace({"Java Developer junior":"Java Developer"},inplace = True)
df['Position'].value_counts()
# Out:
# Java Developer                58
# QA                            36
# Software Engineer             29
# Undefined                     28
# Senior Software Engineer      16
#                               ..
# SharePoint Developer           1
# TA Engineer                    1
# Site Reliability engineer      1
# Graphic Designer               1
# DWH expert                     1
# Name: Position, Length: 371, dtype: int64

# %%
df['Position'].replace({"Software Developer":"Software Engineer"},inplace = True)
df['Position'].replace({"Senior Software Engieer":"Software Engineer"},inplace = True)
df['Position'].replace({"Software engineer ( React/React-native)":"Software Engineer"},inplace = True)
df['Position'].replace({"Senior Software Developer":"Software Engineer"},inplace = True)
df['Position'].replace({"Software Architect":"Software Engineer"},inplace = True)
df['Position'].replace({"Embedded Software Engineer":"Software Engineer"},inplace = True)
df['Position'].replace({"C++ Software EnginÐµer":"Software Engineer"},inplace = True)
df['Position'].replace({"Javascript software developer":"Software Engineer"},inplace = True)
df['Position'].replace({"Principal Software Engineer":"Software Engineer"},inplace = True)
df['Position'].replace({"Senior Software Engineer":"Software Engineer"},inplace = True)
df['Position'].replace({"Seniour software developer":"Software Engineer"},inplace = True)
df['Position'].replace({"Software Engineer JavaSctipt":"Software Engineer"},inplace = True)
df['Position'].replace({"Software Engineer (Android)":"Software Engineer"},inplace = True)
df['Position'].replace({"Lead Software Engineer":"Software Engineer"},inplace = True)
df['Position'].replace({"Senior software engineer":"Software Engineer"},inplace = True)
df['Position'].replace({"Low level software developer":"Software Engineer"},inplace = True)
df['Position'].replace({"Senior Software engineer C++":"Software Engineer"},inplace = True)
df['Position'].replace({"Software Engineer 2(Frontend)":"Software Engineer"},inplace = True)
df['Position'].replace({"Senior Software Engineer (Data Engineer)":"Software Engineer"},inplace = True)
df['Position'].replace({"Software Architekt":"Software Engineer"},inplace = True)
df['Position'].replace({"Software Test Engineer":"Software Engineer"},inplace = True)
df['Position'].replace({"Software Developer (Python Backend)":"Software Engineer"},inplace = True)
df['Position'].replace({"C++ Software Engineer":"Software Engineer"},inplace = True)
df['Position'].replace({"Software Developement Engineer":"Software Engineer"},inplace = True)
df['Position'].replace({"Softwaredeveloper":"Software Engineer"},inplace = True)
df['Position'].replace({"Head of Software Engineering":"Software Engineer"},inplace = True)
df['Position'].replace({"Principal Software Engineer":"Software Engineer"},inplace = True)
df['Position'].replace({"Lead software engineer":"Software Engineer"},inplace = True)
df['Position'].replace({"Softwareentwickler":"Software Engineer"},inplace = True)
df['Position'].value_counts()
# Out:
# Software Engineer           89
# Java Developer              58
# QA                          36
# Undefined                   28
# Frontend Developer          13
#                             ..
# Senior Research Engineer     1
# Operations manager           1
# SharePoint Developer         1
# TA Engineer                  1
# DWH expert                   1
# Name: Position, Length: 349, dtype: int64

# %%
df['Position'].replace({"Software Test Engineer":"Testing"},inplace = True)
df['Position'].replace({"Test Engineer":"Testing"},inplace = True)
df['Position'].replace({"Automation Test Engineer":"Testing"},inplace = True)
df['Position'].replace({"Werkstudent Testautomatisierung":"Testing"},inplace = True)
df['Position'].replace({"Senior Automation Test Engineer":"Testing"},inplace = True)
df['Position'].replace({"Test Automation Engineer":"Testing"},inplace = True)
df['Position'].replace({"QA Test Engineer":"Testing"},inplace = True)
df['Position'].replace({"Javascript Developer in Test":"Testing"},inplace = True)
df['Position'].replace({"Python Test Automation Engineer":"Testing"},inplace = True)
df['Position'].replace({"Senior Software Testing Engineer":"Testing"},inplace = True)
df['Position'].replace({"Gruppenleiter Testing":"Testing"},inplace = True)
df['Position'].replace({"Software tester":"Testing"},inplace = True)
df['Position'].value_counts()
# Out:
# Software Engineer           89
# Java Developer              58
# QA                          36
# Undefined                   28
# Frontend Developer          13
#                             ..
# Data science team lead       1
# Senior Research Engineer     1
# Operations manager           1
# SharePoint Developer         1
# DWH expert                   1
# Name: Position, Length: 340, dtype: int64

# %%
df['Position'].value_counts().plot(kind='barh',figsize = (10,70), orientation=u'horizontal', align='edge')
# Out:
# <AxesSubplot:>

# %%
df1 = df[df['Position'].str.contains('Front')]
df1
# Out:
#                Age     Gender       City                   Position  \
# 3             25.0          M    München  Senior Frontend Developer
# 9             30.0          M    München         Frontend Developer
# 13            29.0          M     Berlin         Front-end engineer
# 18            44.0          M     Berlin         Frontend Developer
# 22            28.0          M    München          Frontend Engineer
# 26            39.0          M    München         Frontend Developer
# 42   Not mentioned          M    München  Senior Frontend Developer
# 50            33.0          M     Berlin         Frontend Developer
# 67            25.0          M  Frankfurt         Frontend Developer
# 71            32.0          M     Berlin         Frontend developer
# 76            28.0          M    München               FrontEnd dev
# 87            24.0  Undefined    München         Frontend Developer
# 95            31.0          M     Berlin         Frontend developer
# ...

# %%
df['Position'].replace({"Senior Frontend Developer":"Frontend Developer"},inplace = True)
df['Position'].replace({"Front-end engineer":"Frontend Developer"},inplace = True)
df['Position'].replace({"Frontend Engineer":"Frontend Developer"},inplace = True)
df['Position'].replace({"Frontend developer":"Frontend Developer"},inplace = True)
df['Position'].replace({"FrontEnd dev":"Frontend Developer"},inplace = True)
df['Position'].replace({"Front-end developer":"Frontend Developer"},inplace = True)
df['Position'].replace({"FrontEnd Developer":"Frontend Developer"},inplace = True)
df['Position'].replace({"Frontent Developer":"Frontend Developer"},inplace = True)
df['Position'].replace({"Frontend":"Frontend Developer"},inplace = True)
df['Position'].replace({"Front End Engineer":"Frontend Developer"},inplace = True)
df['Position'].replace({"Front End developer":"Frontend Developer"},inplace = True)
df['Position'].replace({"Front End Developer":"Frontend Developer"},inplace = True)
df['Position'].value_counts()
# Out:
# Software Engineer           89
# Java Developer              58
# QA                          36
# Frontend Developer          31
# Undefined                   28
#                             ..
# Senior Research Engineer     1
# Operations manager           1
# SharePoint Developer         1
# TA Engineer                  1
# DWH expert                   1
# Name: Position, Length: 329, dtype: int64

# %%
df[df['Position'].str.contains('ios')]
# Out:
#                Age Gender     City       Position  Years of experience  \
# 349           30.0      F  München  ios developer                  7.0
# 453  Not mentioned      M   Berlin  ios вумудщзук                 30.0
#
#     Seniority Level  Yearly Salary  Salary one year ago  Salary two years ago  \
# 349          Senior        60000.0              60000.0                   NaN
# 453          Senior        65000.0              56000.0               47000.0
#
#     Are you getting any Stock Options? Main language at work Company size  \
# 349                                 No               English        10-50
# 453                                 No               English       50-100
#
#     Company type
# 349      Startup
# 453      Startup

# %%
df[df['Position'].str.contains('iOS')]
# Out:
#                Age Gender       City              Position  \
# 29            31.0      M     Berlin        iOS Developer
# 44            24.0      F    München         iOS developer
# 46            28.0      M    München         iOS Developer
# 64            29.0      M  Frankfurt         iOS developer
# 66            29.0      M     Lisbon         iOS developer
# 73   Not mentioned      M    Leipzig         iOS Developer
# 84            30.0      M     Berlin         iOS Developer
# 251  Not mentioned      M  Stuttgart         iOS Developer
# 267           27.0      M    München         iOS Developer
# 313           33.0      M    München         iOS Developer
# 328           30.0      M     Berlin         iOS Developer
# 344           36.0      M    Dublin         iOS developer
# 362           26.0      M    München         iOS Developer
# 419           30.0      M    München  Senior iOS Developer
# 436           22.0      M    München         iOS Developer
# ...

# %%
df['Position'].replace({"iOS Developer":"iOS Developer"},inplace = True)
df['Position'].replace({"iOS developer":"iOS Developer"},inplace = True)
df['Position'].replace({"Senior iOS developer":"iOS Developer"},inplace = True)
df['Position'].replace({"ios вумудщзук":"iOS Developer"},inplace = True)
df['Position'].replace({"iOS Developwr 	":"iOS Developer"},inplace = True)
df['Position'].replace({"Senior iOS Developer":"iOS Developer"},inplace = True)
df['Position'].replace({"ios developer":"iOS Developer"},inplace = True)
df['Position'].value_counts().plot(kind='barh',figsize = (10,70), orientation=u'horizontal', align='edge')
# Out:
# <AxesSubplot:>

# %%
df[df['Position'].str.contains('data')]
# Out:
#       Age Gender     City        Position  Years of experience  \
# 622  30.0      M  München  data scientist                  5.0
#
#     Seniority Level  Yearly Salary  Salary one year ago  Salary two years ago  \
# 622          Middle        60000.0              59000.0               58000.0
#
#     Are you getting any Stock Options? Main language at work Company size  \
# 622                                 No               English     100-1000
#
#     Company type
# 622      Product

# %%
df[df['Position'].str.contains('Data')]
# Out:
#                Age Gender        City                               Position  \
# 7             36.0      F     München                 Data science team lead
# 45            43.0      M      Berlin                          Data Engineer
# 99            32.0      F      Berlin                          Data Engineer
# 100           22.0      M      Berlin                         Data scientist
# 113           32.0      M     München                         Data Scientist
# 157           27.0      M      Berlin                         Data Scientist
# 164           37.0      M      Berlin                 Database Administrator
# 185           29.0      M      Berlin                         Data scientist
# 202           30.0      M        Köln                         Data scientist
# 203           36.0      M     München                         Data Scientist
# 222           30.0      M      Berlin                  Senior Data Scientist
# ...

# %%
df['Position'].replace({"data scientist":"Data Scientist"},inplace = True)
df['Position'].replace({"Data science team lead":"Data Scientist"},inplace = True)
df['Position'].replace({"Data scientist":"Data Scientist"},inplace = True)
df['Position'].replace({"Data Scientist":"Data Scientist"},inplace = True)
df['Position'].replace({"Senior Data Scientist":"Data Scientist"},inplace = True)
df['Position'].replace({"Head of Data Science":"Data Scientist"},inplace = True)
df['Position'].replace({"Data Science Team Lead":"Data Scientist"},inplace = True)

df['Position'].value_counts()
# Out:
# Software Engineer     89
# Java Developer        58
# QA                    36
# Frontend Developer    31
# Undefined             28
#                       ..
# SAP Developer          1
# C# dev                 1
# QA automation          1
# BA/PM                  1
# DWH expert             1
# Name: Position, Length: 318, dtype: int64

# %%
dfpositions = pd.DataFrame(df['Position'].value_counts())
dfpositions
# Out:
#                     Position
# Software Engineer         89
# Java Developer            58
# QA                        36
# Frontend Developer        31
# Undefined                 28
# ...                      ...
# SAP Developer              1
# C# dev                     1
# QA automation              1
# BA/PM                      1
# DWH expert                 1
#
# [318 rows x 1 columns]

# %%
pd.set_option('display.max_rows', None)
dfpositions
# Out:
#                                                   Position
# Software Engineer                                       89
# Java Developer                                          58
# QA                                                      36
# Frontend Developer                                      31
# Undefined                                               28
# Data Scientist                                          21
# iOS Developer                                           20
# Testing                                                 12
# DevOps                                                  11
# Android Developer                                        8
# PHP Developer                                            7
# CTO                                                      6
# Project Manager                                          6
# Software developer                                       6
# Team Lead                                                6
# ...

# %%
df.to_csv('IT Salary Survey2018_Cleaned_Update 1.1.csv',index = False)
